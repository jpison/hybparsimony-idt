# %%
import openml
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import warnings
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
warnings.filterwarnings("ignore")

# List all datasets and their properties
datasets_openml = openml.datasets.list_datasets(output_format="dataframe")
print(datasets_openml.shape)
# Get small datasets with more than 10 features
selec_datasets = datasets_openml.query('NumberOfInstances>1000 and NumberOfInstances<30000 and NumberOfFeatures>10 and NumberOfFeatures<500')
print(selec_datasets.shape)

res_datasets = []
for name_ds in tqdm(selec_datasets.name):
    try:
        # Get dataset by name
        dataset = openml.datasets.get_dataset(name_ds)
        # Get the data itself as a dataframe (or otherwise)
        X, y, _, _ = dataset.get_data(dataset_format="dataframe", target=dataset.default_target_attribute)
        if y is not None:
            # print(name_ds, y.dtypes, len(y), len(np.unique(y)))
            res_datasets.append(dict(id_ds=dataset.dataset_id,
                                    name_ds=name_ds, 
                                    nrows=X.shape[0],
                                    len_y=len(y),
                                    type_y=y.dtypes,
                                    num_classes=len(np.unique(y)),
                                    target_name=dataset.default_target_attribute))
    except:
        continue
res_datasets = pd.DataFrame(res_datasets)
res_datasets.to_csv('res_datasets.csv', index=False)

print(res_datasets.shape)
 
res_selec = res_datasets.query('type_y!="object" and type_y!="Sparse[float64, 0]" and len_y>2000 and type_y!="int64" and nrows<40000')
print(res_selec.shape)

res_selec = res_selec.drop_duplicates()
print(res_selec.shape)

# Remove datasets with similar name
selec_names = []
pos_selec = []
for nrow, name_ds in enumerate(res_selec.name_ds.values):
    three = name_ds[:3]
    if three not in selec_names:
        selec_names.append(three)
        pos_selec.append(nrow)
res_selec = res_selec.iloc[pos_selec]
print(res_selec.shape) 
print(res_selec.head())
# Out:
# (911, 7)
# (300, 7)
# (158, 7)
# (117, 7)
#    id_ds      name_ds  nrows  len_y    type_y  num_classes target_name
# 0      3     kr-vs-kp   3196   3196  category            2       class
# 1      6       letter  20000  20000  category           26       class
# 7     24     mushroom   8124   8124  category            2       class
# 8     28    optdigits   5620   5620  category           10       class
# 9     30  page-blocks   5473   5473  category            5       class

# %%
warnings.filterwarnings("ignore")
# Inputs
# array(['bool', 'category', 'float64', 'int64', 'object', 'uint8'],

# Outputs
# array(['bool', 'category', 'float64', 'uint8'], dtype='<U8')

scaler = StandardScaler()
label_enc = LabelEncoder()
res_basedata = []
for nrow, row in res_selec.iterrows():
    # try:
    # Get dataset by name
    dataset = openml.datasets.get_dataset(row['name_ds'])
    # Get the data itself as a dataframe (or otherwise)
    X, y, _, _ = dataset.get_data(dataset_format="dataframe", target=dataset.default_target_attribute)
    assert y.isna().sum()==0
    
    # Transform Inputs
    # ----------------
    X_prim = []
    for namecol in X.columns:
        # Convert numeric to float64
        if X[namecol].dtypes==np.uint8 or X[namecol].dtypes==np.int64 or X[namecol].dtypes==np.float64 or X[namecol].dtypes==bool:
            X[namecol] = X[namecol].astype(np.float64)
            X[namecol] = X[namecol].fillna(X[namecol].mean())
            X[namecol] = scaler.fit_transform(X[namecol].values.reshape(-1,1)).flatten()
            X_prim.append(X[namecol])
        if str(X[namecol].dtypes)=='category' or str(X[namecol].dtypes)=='object':
            X_prim.append(pd.get_dummies(X[namecol], prefix=namecol).astype(np.float32))
    X_prim = pd.concat(X_prim, axis=1)
    
    # Transform Target
    # --------------
    if row['type_y'] == 'float64':
        y.fillna(y.mean(), inplace=True)
        y_values = y.values.flatten()
        y_values = scaler.fit_transform(y_values.reshape(-1,1)).flatten()
        type_prob = 'regression'
    if row['type_y'] == 'uint8':
        y = y.astype(np.int32)
        y_values = y.values.flatten()
        type_prob = 'binary' if row['num_classes']==2 else 'multiclass'
        
    if row['type_y'] == 'bool':
        y = y.astype(np.int32)
        y_values = y.values.flatten()
        type_prob = 'binary' if row['num_classes']==2 else 'multiclass'
    if row['type_y'] == 'category':
        y_values = label_enc.fit_transform(y)
        type_prob = 'binary' if row['num_classes']==2 else 'multiclass'
    
    name_file = row['name_ds'].replace('-','_').split('_')[0]
    print(name_file)
    
    # Include more 
    row['name_file'] = name_file + '.csv'
    row['type_prob'] = type_prob
    row['NFs'] = X_prim.shape[1]
    X_prim['target_end'] = y_values
    res_basedata.append(row)
    
    if type_prob == 'regression':
        print(row['name_ds'], X.shape, X_prim.shape, type_prob, X_prim['target_end'].mean(), X_prim['target_end'].std())
    if type_prob == 'binary' or type_prob == 'multiclass':
        print(row['name_ds'], X.shape, X_prim.shape, type_prob, X_prim['target_end'].nunique())
    X_prim.to_csv('./datasets/' + row['name_file'], index=False)

res_basedata = pd.DataFrame(res_basedata)
res_basedata.to_csv('res_basedata.csv', index=False)
# Out:
# kr
# kr-vs-kp (3196, 36) (3196, 75) binary 2
# letter
# letter (20000, 16) (20000, 17) multiclass 26
# mushroom
# mushroom (8124, 22) (8124, 126) binary 2
# optdigits
# optdigits (5620, 64) (5620, 65) multiclass 10
# page
# page-blocks (5473, 10) (5473, 11) multiclass 5
# pendigits
# pendigits (10992, 16) (10992, 17) multiclass 10
# segment
# segment (2310, 19) (2310, 20) multiclass 7
# sick
# sick (3772, 29) (3772, 53) binary 2
# spambase
# spambase (4601, 57) (4601, 58) binary 2
# splice
# splice (3190, 60) (3190, 288) multiclass 3
# hypothyroid
# hypothyroid (3772, 29) (3772, 53) multiclass 4
# waveform
# waveform-5000 (5000, 40) (5000, 41) multiclass 3
# satimage
# satimage (6430, 36) (6430, 37) multiclass 6
# cpu
# cpu_act (8192, 21) (8192, 22) multiclass 56
# pol
# pol (15000, 48) (15000, 49) multiclass 11
# elevators
# elevators (16599, 18) (16599, 19) regression -9.237612047534769e-16 1.0000301236576215
# wine
# wine_quality (6497, 11) (6497, 12) multiclass 7
# Ailerons
# Ailerons (13750, 40) (13750, 41) regression -1.0748573748225515e-16 1.000036365619955
# coil2000
# coil2000 (9822, 85) (9822, 86) binary 2
# ozone
# ozone_level (2536, 72) (2536, 22709) binary 2
# puma32H
# puma32H (8192, 32) (8192, 33) regression 8.673617379884035e-18 1.0000610407447539
# scene
# scene (2407, 299) (2407, 305) binary 2
# yeast
# yeast_ml8 (2417, 116) (2417, 130) binary 2
# internet
# internet_usage (10108, 71) (10108, 10653) multiclass 46
# JapaneseVowels
# JapaneseVowels (9961, 14) (9961, 15) multiclass 9
# ipums
# ipums_la_99-small (8844, 60) (8844, 9984) multiclass 7
# mtp
# mtp (4450, 202) (4450, 203) regression -2.04380831859085e-16 1.0001123784911115
# yprop
# yprop_4_1 (8885, 251) (8885, 252) regression 2.7574016352288414e-15 1.0000562793708412
# topo
# topo_2_1 (8885, 266) (8885, 267) regression 2.7574016352288414e-15 1.0000562793708412
# cjs
# cjs (2796, 34) (2796, 100) multiclass 6
# bank32nh
# bank32nh (8192, 32) (8192, 33) regression 3.122502256758253e-17 1.000061040744754
# house
# house_16H (22784, 16) (22784, 17) regression -4.459603722511162e-17 1.000021945947135
# ailerons
# ailerons (13750, 40) (13750, 41) regression -1.0748573748225515e-16 1.000036365619955
# kdd
# kdd_internet_usage (10108, 68) (10108, 576) binary 2
# ada
# ada_prior (4562, 14) (4562, 103) binary 2
# sylva
# sylva_prior (14395, 108) (14395, 109) binary 2
# eye
# eye_movements (10936, 27) (10936, 31) multiclass 3
# jm1
# jm1 (10885, 21) (10885, 22) binary 2
# mc1
# mc1 (9466, 38) (9466, 39) binary 2
# kc1
# kc1 (2109, 21) (2109, 22) binary 2
# pc2
# pc2 (5589, 36) (5589, 37) binary 2
# MagicTelescope
# MagicTelescope (19020, 10) (19020, 11) binary 2
# Kaggle
# Kaggle_bike_sharing_demand_challange (10886, 10) (10886, 48) regression -6.266039190976448e-17 1.0000459337176697
# cardiotocography
# cardiotocography (2126, 35) (2126, 36) multiclass 10
# eeg
# eeg-eye-state (14980, 14) (14980, 15) binary 2
# first
# first-order-theorem-proving (6118, 51) (6118, 52) multiclass 6
# gas
# gas-drift (13910, 128) (13910, 129) multiclass 6
# ringnorm
# ringnorm (7400, 20) (7400, 21) binary 2
# wall
# wall-robot-navigation (5456, 24) (5456, 25) multiclass 4
# twonorm
# twonorm (7400, 20) (7400, 21) binary 2
# autoUniv
# autoUniv-au4-2500 (2500, 100) (2500, 227) multiclass 3
# CreditCardSubset
# CreditCardSubset (14240, 30) (14240, 31) binary 2
# PhishingWebsites
# PhishingWebsites (11055, 30) (11055, 69) binary 2
# GesturePhaseSegmentationProcessed
# GesturePhaseSegmentationProcessed (9873, 32) (9873, 33) multiclass 5
# BachChoralHarmony
# BachChoralHarmony (5665, 16) (5665, 105) multiclass 102
# thyroid
# thyroid-allbp (2800, 26) (2800, 47) multiclass 5
# texture
# texture (5500, 40) (5500, 41) multiclass 11
# SpeedDating
# SpeedDating (8378, 120) (8378, 501) binary 2
# clean2
# clean2 (6598, 168) (6598, 169) binary 2
# dna
# dna (3186, 180) (3186, 361) multiclass 3
# led24
# led24 (3200, 24) (3200, 49) multiclass 10
# churn
# churn (5000, 20) (5000, 34) binary 2
# allbp
# allbp (3772, 29) (3772, 55) multiclass 3
# dis
# dis (3772, 29) (3772, 55) binary 2
# Satellite
# Satellite (5100, 36) (5100, 37) binary 2
# Titanic
# Titanic (2201, 3) (2201, 4) binary 2
# jungle
# jungle_chess_2pcs_endgame_panther_lion (4704, 46) (4704, 76) multiclass 3
# USPS
# USPS (9298, 256) (9298, 257) multiclass 10
# jasmine
# jasmine (2984, 144) (2984, 281) binary 2
# madeline
# madeline (3140, 259) (3140, 260) binary 2
# philippine
# philippine (5832, 308) (5832, 309) binary 2
# test
# test_dataset (15547, 60) (15547, 61) binary 2
# microaggregation2
# microaggregation2 (20000, 20) (20000, 21) multiclass 5
# CPMP
# CPMP-2015-regression (2108, 26) (2108, 561) regression 8.089670615864518e-17 1.0002372760740474
# ASP
# ASP-POTASSCO-regression (14234, 142) (14234, 1451) regression 7.188292394931462e-17 1.000035129011305
# Indian
# Indian_pines (9144, 220) (9144, 221) multiclass 8
# SAT11
# SAT11-HAND-runtime-regression (4440, 116) (4440, 131) regression -1.9203857723245952e-16 1.0001126316385844
# employee
# employee_salaries (9228, 12) (9228, 12731) regression -1.8113911853875548e-16 1.0000541873256243
# dataset
# dataset_sales (10738, 14) (10738, 15) multiclass 51
# compas
# compas-two-years (5278, 13) (5278, 20) binary 2
# Mercedes
# Mercedes_Benz_Greener_Manufacturing (4209, 376) (4209, 564) regression -5.199504932623209e-16 1.0001188142343644
# Long
# Long (4477, 19) (4477, 20) binary 2
# speeddating
# speeddating (8378, 120) (8378, 501) binary 2
# shill
# shill-bidding (6321, 12) (6321, 1066) binary 2
# MiamiHousing2016
# MiamiHousing2016 (13932, 16) (13932, 17) regression -1.6320246586508188e-17 1.0000358905338833
# superconduct
# superconduct (21263, 81) (21263, 82) regression 8.554716660611656e-17 1.000023515855569
# IEEE80211aa
# IEEE80211aa-GATS (4046, 33) (4046, 36) regression -1.9669003066023535e-16 1.000123601755617
# Minneapolis
# Minneapolis-Air-Quality-Survey (4790, 17) (4790, 800) regression 2.6700979631903555e-17 1.0001044004805266
# law
# law-school-admission-bianry (20800, 11) (20800, 20) binary 2
# national
# national-longitudinal-survey-binary (4908, 16) (4908, 81) binary 2
# ames
# ames_housing (2930, 80) (2930, 355) regression -1.0185254232738638e-16 1.0001706921579385
# avocado
# avocado_sales (18249, 13) (18249, 68) regression 1.619736851751886e-16 1.0000273998876656
# rl
# rl (31406, 22) (31406, 7440) binary 2
# credit
# credit (16714, 10) (16714, 11) binary 2
# VulNoneVul
# VulNoneVul (5692, 16) (5692, 17) binary 2
# Intersectional
# Intersectional-Bias-Assessment-(Training-Data) (10000, 18) (10000, 25) binary 2
# UCI
# UCI_churn (3333, 20) (3333, 3405) binary 2
# turing
# turing_binary (10000, 22) (10000, 27) binary 2
# Job
# Job_Profitability (14480, 29) (14480, 33) regression 1.9628252369063543e-18 1.0000345321753648
# ECG5000
# ECG5000 (4998, 140) (4998, 141) binary 2
# naval
# naval_propulsion_plant (11934, 14) (11934, 15) regression -7.621038225011968e-17 1.000041899733955
# white
# white_wine (4898, 11) (4898, 12) multiclass 7
# grid
# grid_stability (10000, 12) (10000, 13) regression -3.943512183468556e-17 1.0000500037503126
# miami
# miami_housing (13932, 15) (13932, 16) regression -1.6320246586508188e-17 1.0000358905338833
# kings
# kings_county (21613, 21) (21613, 133) regression -3.6820796004780096e-17 1.0000231350275917
# fps
# fps_benchmark (24624, 43) (24624, 958) regression -4.365867280722188e-16 1.0000203060115969
# health
# health_insurance (22272, 11) (22272, 26) multiclass 75
# fifa
# fifa (18063, 5) (18063, 6) regression -2.769318972347398e-16 1.0000276820440475
# default
# default-of-credit-card-clients (30000, 23) (30000, 24) binary 2
# Bioresponse
# Bioresponse (3751, 1776) (3751, 1777) binary 2
# heloc
# heloc (10000, 22) (10000, 23) binary 2
# online
# online_shoppers (12330, 17) (12330, 14568) binary 2
# shrutime
# shrutime (10000, 10) (10000, 29) binary 2
# Insurance
# Insurance (23548, 10) (23548, 74) binary 2
# Contaminant
# Contaminant-detection-in-packaged-cocoa-hazelnut-spread-jars-using-Microwaves-Sensing-and-Machine-Learning-9.0GHz(Urbinati) (2400, 30) (2400, 31) binary 2
# FICO
# FICO-HELOC-cleaned (9871, 23) (9871, 40) binary 2
# COIL2000
# COIL2000-train (5822, 85) (5822, 151) binary 2

# %%
res_basedata
# Out:
# [id_ds                 3
#  name_ds        kr-vs-kp
#  nrows              3196
#  len_y              3196
#  type_y         category
#  num_classes           2
#  target_name       class
#  name_file        kr.csv
#  type_prob        binary
#  NFs                  74
#  Name: 0, dtype: object,
#  id_ds                   6
#  name_ds            letter
#  nrows               20000
#  len_y               20000
#  type_y           category
#  num_classes            26
#  target_name         class
#  name_file      letter.csv
#  type_prob      multiclass
#  NFs                    16
#  Name: 1, dtype: object,
#  id_ds                    24
#  name_ds            mushroom
#  nrows                  8124
#  len_y                  8124
#  type_y             category
#  num_classes               2
#  target_name           class
#  name_file      mushroom.csv
#  type_prob            binary
#  NFs                     125
#  Name: 7, dtype: object,
#  id_ds                     28
#  name_ds            optdigits
#  nrows                   5620
#  len_y                   5620
#  type_y              category
#  num_classes               10
#  target_name            class
#  name_file      optdigits.csv
#  type_prob         multiclass
#  NFs                       64
#  Name: 8, dtype: object]

# %%
import os

FOLDER_DATASETS = "datasets/"
df = pd.read_csv("res_basedata.csv") # Este es el de Pisón del artículo de HYBparsimony. Me voy a quedar solo con los binarios.
df = df.loc[df['type_prob'] == "binary"]
print("Number of selected datasets =", df.shape[0])
df.to_csv("datasets.csv",index=False)

# Borramos todos los datasets que no sean de clasificación binaria de la carpeta datasets
name_datasets = list(df["name_file"])

list_files = os.listdir(FOLDER_DATASETS)
print(list_files)
print(name_datasets)
for file in list_files:
    if file not in name_datasets:
        os.remove(FOLDER_DATASETS + file)
        print("Removed", file)
# Out:
# Number of selected datasets = 53
# ['ada.csv', 'Ailerons.csv', 'allbp.csv', 'ames.csv', 'ASP.csv', 'autoUniv.csv', 'avocado.csv', 'BachChoralHarmony.csv', 'bank32nh.csv', 'Bioresponse.csv', 'cardiotocography.csv', 'churn.csv', 'cjs.csv', 'clean2.csv', 'coil2000.csv', 'compas.csv', 'Contaminant.csv', 'CPMP.csv', 'cpu.csv', 'credit.csv', 'CreditCardSubset.csv', 'dataset.csv', 'default.csv', 'dis.csv', 'dna.csv', 'ECG5000.csv', 'eeg.csv', 'elevators.csv', 'employee.csv', 'eye.csv', 'FICO.csv', 'fifa.csv', 'first.csv', 'fps.csv', 'gas.csv', 'GesturePhaseSegmentationProcessed.csv', 'grid.csv', 'health.csv', 'heloc.csv', 'house.csv', 'hypothyroid.csv', 'IEEE80211aa.csv', 'Indian.csv', 'Insurance.csv', 'internet.csv', 'Intersectional.csv', 'ipums.csv', 'JapaneseVowels.csv', 'jasmine.csv', 'jm1.csv', 'Job.csv', 'jungle.csv', 'Kaggle.csv', 'kc1.csv', 'kdd.csv', 'kings.csv', 'kr.csv', 'law.csv', 'led24.csv', 'letter.csv', 'Long.csv', 'madeline.csv', 'MagicTelescope.csv', 'mc1.csv', 'Mercedes.csv', 'miami.csv', 'MiamiHousing2016.csv', 'microaggregation2.csv', 'Minneapolis.csv', 'mtp.csv', 'mushroom.csv', 'national.csv', 'naval.csv', 'online.csv', 'optdigits.csv', 'ozone.csv', 'page.csv', 'pc2.csv', 'pendigits.csv', 'philippine.csv', 'PhishingWebsites.csv', 'pol.csv', 'puma32H.csv', 'ringnorm.csv', 'rl.csv', 'SAT11.csv', 'Satellite.csv', 'satimage.csv', 'scene.csv', 'segment.csv', 'shill.csv', 'shrutime.csv', 'sick.csv', 'spambase.csv', 'SpeedDating.csv', 'splice.csv', 'superconduct.csv', 'sylva.csv', 'test.csv', 'texture.csv', 'thyroid.csv', 'Titanic.csv', 'topo.csv', 'turing.csv', 'twonorm.csv', 'UCI.csv', 'USPS.csv', 'VulNoneVul.csv', 'wall.csv', 'waveform.csv', 'white.csv', 'wine.csv', 'yeast.csv', 'yprop.csv']
# ['kr.csv', 'mushroom.csv', 'sick.csv', 'spambase.csv', 'coil2000.csv', 'ozone.csv', 'scene.csv', 'yeast.csv', 'kdd.csv', 'ada.csv', 'sylva.csv', 'jm1.csv', 'mc1.csv', 'kc1.csv', 'pc2.csv', 'MagicTelescope.csv', 'eeg.csv', 'ringnorm.csv', 'twonorm.csv', 'CreditCardSubset.csv', 'PhishingWebsites.csv', 'SpeedDating.csv', 'clean2.csv', 'churn.csv', 'dis.csv', 'Satellite.csv', 'Titanic.csv', 'jasmine.csv', 'madeline.csv', 'philippine.csv', 'test.csv', 'compas.csv', 'Long.csv', 'speeddating.csv', 'shill.csv', 'law.csv', 'national.csv', 'rl.csv', 'credit.csv', 'VulNoneVul.csv', 'Intersectional.csv', 'UCI.csv', 'turing.csv', 'ECG5000.csv', 'default.csv', 'Bioresponse.csv', 'heloc.csv', 'online.csv', 'shrutime.csv', 'Insurance.csv', 'Contaminant.csv', 'FICO.csv', 'COIL2000.csv']
# Removed Ailerons.csv
# Removed allbp.csv
# Removed ames.csv
# Removed ASP.csv
# Removed autoUniv.csv
# Removed avocado.csv
# Removed BachChoralHarmony.csv
# Removed bank32nh.csv
# Removed cardiotocography.csv
# Removed cjs.csv
# Removed CPMP.csv
# Removed cpu.csv
# Removed dataset.csv
# Removed dna.csv
# Removed elevators.csv
# Removed employee.csv
# Removed eye.csv
# Removed fifa.csv
# Removed first.csv
# Removed fps.csv
# Removed gas.csv
# Removed GesturePhaseSegmentationProcessed.csv
# Removed grid.csv
# Removed health.csv
# Removed house.csv
# Removed hypothyroid.csv
# Removed IEEE80211aa.csv
# Removed Indian.csv
# Removed internet.csv
# Removed ipums.csv
# Removed JapaneseVowels.csv
# Removed Job.csv
# Removed jungle.csv
# Removed Kaggle.csv
# Removed kings.csv
# Removed led24.csv
# Removed letter.csv
# Removed Mercedes.csv
# Removed miami.csv
# Removed MiamiHousing2016.csv
# Removed microaggregation2.csv
# Removed Minneapolis.csv
# Removed mtp.csv
# Removed naval.csv
# Removed optdigits.csv
# Removed page.csv
# Removed pendigits.csv
# Removed pol.csv
# Removed puma32H.csv
# Removed SAT11.csv
# Removed satimage.csv
# Removed segment.csv
# Removed splice.csv
# Removed superconduct.csv
# Removed texture.csv
# Removed thyroid.csv
# Removed topo.csv
# Removed USPS.csv
# Removed wall.csv
# Removed waveform.csv
# Removed white.csv
# Removed wine.csv
# Removed yprop.csv
